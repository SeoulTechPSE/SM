# %% [markdown]
# # SAMSON
#
# * Avogadro와 비슷하게 화합물의 구조를 확인할 수 있는 프로그램
# * [SAMSON 홈페이지](https://samson-connect.net/app/main?execution=e1s2)

# %% [markdown]
# ## SAMSON 의 기능
#
# 아래에 보이는 기능 이외에도 SAMSON 홈페이지에서 `Element`에서 다양한 기능을 추가 다운로드하여 이용할 수 있다.
# ![SAMSON-06.PNG](attachment:SAMSON-06.PNG)<br>
#
# > `Document view` , `Inspector` , `History` 보기.<br>
# * Document view : 현재 Layer, 화합물 등을 볼 수 있다.
# * Inspector : 원자, 결합을 클릭하여 그것의 성질, 결합 길이, 종류 등을 확인하고, 설정할 수 있다.
# * History : 화합물을 불러오거나, 삭제, 이동 등 수정사항의 기록된 로그를 확인할 수 있다.
# ![SAMSON-07.PNG](attachment:SAMSON-07.PNG)<br>
# ![SAMSON-08.PNG](attachment:SAMSON-08.PNG)

# %% [markdown]
# ### 기본 ToolBar
#
# ![SAMSON-09.PNG](attachment:SAMSON-09.PNG)<br>
# * 위쪽 빨간 박스 - Zoom on Selection : 선택된 부분을 확대해준다.
# * 아래 박스
#
# > 1. `Atom Creator`
# 2. Delegate
# 3. `Eraser`
# 4. Lasso Selection
# 5. `Move Camera` : 다른 툴을 이용 하고 있을 때에도, `Shift + 마우스`로 Move Camera 사용할 수 있다.
# 6. `Periodic Table` : 주기율표 위의 원하는 원자를 선택해 `Atom Creator` 로 만들 수 있다.
# 7. Point Selection
# 8. Rectangle Selection
# 9. `Rotation` : 선택된 부분의 회전.
# 10. `Ruler` : 길이, 각도 측정
# 11. `Translation` : X, Y, Z축의 평행이동
# 12. Twister
#
# >4. Lasso Selection
# ![SAMSON-10.PNG](attachment:SAMSON-10.PNG)
#
# >6. `Periodic Table`
# ![SAMSON-11.PNG](attachment:SAMSON-11.PNG)
#
# > 9. `Rotation`
# ![SAMSON-12.PNG](attachment:SAMSON-12.PNG)
#
# > 10. `Translation`
# ![SAMSON-13.PNG](attachment:SAMSON-13.PNG)

# %% [markdown]
# ### Visualiztion
#
# **Ball & Stick** 형식이 아닌 다른 형식으로 나타낼 수 있다.
#
# ![SAMSON-14.PNG](attachment:SAMSON-14.PNG)
#
# ![SAMSON-15.PNG](attachment:SAMSON-15.PNG)
#
# ![SAMSON-16.PNG](attachment:SAMSON-16.PNG)

# %% [markdown]
# ### Simulator
#
# 임의로 탄소원자 6개를 단일결합으로 이어준 화합물을 `Simulator`를 이용해서 안정화 시켜보자.
#
# ![SAMSON-17.PNG](attachment:SAMSON-17.PNG)
#
# ![SAMSON-18.PNG](attachment:SAMSON-18.PNG)
#
# ![SAMSON-19.PNG](attachment:SAMSON-19.PNG)
#
# ![SAMSON-20.PNG](attachment:SAMSON-20.PNG)
#
# ![SAMSON-21.PNG](attachment:SAMSON-21.PNG)
#
# ![SAMSON-22.PNG](attachment:SAMSON-22.PNG)

# %% [markdown]
# ## Avogadro 와 다른점 <br>
#
# 1. 프로그램 접근성
# 2. 지원 File 형식의 차이
# 3. 단수 / 복수의 Layer
# 4. Stereo 보기 ( 3D 안경 )

# %% [markdown]
# ## 1. 프로그램 접근성
#
# * **Avogadro**는 설치파일을 받고 설치하면 바로 이용이 가능했다.<br>
# **SAMSON**은 홈페이지에서 가입 후 코드를 받아 이를 이용해 프로그램 다운/실행이 가능하다.
# ![samson.PNG](attachment:samson.PNG)
#
# ![SAMSON_%EC%84%A4%EC%B9%98%EC%A4%91%EC%BD%94%EB%93%9C.png](attachment:SAMSON_%EC%84%A4%EC%B9%98%EC%A4%91%EC%BD%94%EB%93%9C.png)
#
# ![SAMSON-%EC%8B%9C%EC%9E%91%ED%99%94%EB%A9%B4_01.PNG](attachment:SAMSON-%EC%8B%9C%EC%9E%91%ED%99%94%EB%A9%B4_01.PNG)

# %% [markdown]
# ## 2. 지원 File 형식의 차이

# %%
from __future__ import print_function #2.X대 python호환을 위해
from rdkit import Chem
from rdkit.Chem import AllChem

# %%
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw

# %%
Chiral1 = Chem.MolFromSmiles('N[C@](C)(F)C(=O)O')

# %%
f = open('Chiral1.mol','w')           # 해당 파일을 읽기 전용 열기
f.write(Chem.MolToMolBlock(Chiral1))  # 해당 파일을 chemical file로 작성
f.close()                             # 닫음으로써 저장

# %% [markdown]
# ### Avogadro 에서 File open
#
# ![Avogadro%20open%20files.PNG](attachment:Avogadro%20open%20files.PNG)
#
# ![Avogadro%20open%20files-1.PNG](attachment:Avogadro%20open%20files-1.PNG)<br>
#
# ### SAMSON 에서 File open
#
# ![SAMSON%20open%20files.PNG](attachment:SAMSON%20open%20files.PNG)
#
# ![SAMSON%20open%20files-1.PNG](attachment:SAMSON%20open%20files-1.PNG)<br>
#
# > Avogadro의 지원 Files 형식 <br>
# ![Avogadro%20open%20files-2.PNG](attachment:Avogadro%20open%20files-2.PNG)
#
# > SAMSON 의 지원 Files 형식 <br>
# ![SAMSON%20open%20files-3.PNG](attachment:SAMSON%20open%20files-3.PNG)<br>
# ![SAMSON%20open%20files-2.PNG](attachment:SAMSON%20open%20files-2.PNG)

# %% [markdown]
# ## 3. 단수 / 복수의 Layer
#
# > SAMSON 에서는 Layer 추가가 가능하다. 이를 이용해 다수의 화합물들을 다른 Layer에서 확인할 수 있다.
#
# ![SAMSON-01.PNG](attachment:SAMSON-01.PNG)
#
# ![SAMSON-02.PNG](attachment:SAMSON-02.PNG)
#
# ![SAMSON-03.PNG](attachment:SAMSON-03.PNG)

# %% [markdown]
# ## 4. Stereo 보기 ( 3D 안경 )
# SAMSON 에서 Stereo on 으로 3D로 관찰 할 수 있다.
#
# ![SAMSON-04.PNG](attachment:SAMSON-04.PNG)
#
# ![SAMSON-05.PNG](attachment:SAMSON-05.PNG)
